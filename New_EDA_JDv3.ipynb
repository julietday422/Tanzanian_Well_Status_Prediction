# %%
# Import packages
import pandas as pd
import numpy as np
# import pandas_profiling as pp
# from pandas_profiling import ProfileReport
from sklearn.preprocessing import OneHotEncoder
from sklearn.dummy import DummyClassifier

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn import preprocessing
from sklearn.impute import SimpleImputer

# %%
# import data

# %%
df_ind = pd.read_csv("Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_values.csv", parse_dates=["date_recorded"])

# %%
df_dep = pd.read_csv("Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_labels.csv")

# %%
# Shows all columns in dataframe

pd.set_option('display.max_columns', None)

# Converts from scientific notation to standard form (applied to every df in
# this notebook) and rounds to two decimal places

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
#look at each dataframe

# %%
df_ind.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572     6000.00    2011-03-14         Roman        1390         Roman
# 1   8776        0.00    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310       25.00    2013-02-25  Lottery Club         686  World vision
# 3  67743        0.00    2013-01-28        Unicef         263        UNICEF
# 4  19728        0.00    2011-07-13   Action In A           0       Artisan
#
#    longitude  latitude              wpt_name  num_private  \
# 0      34.94     -9.86                  none            0
# 1      34.70     -2.15              Zahanati            0
# 2      37.46     -3.82           Kwa Mahundi            0
# 3      38.49    -11.16  Zahanati Ya Nanyumbu            0
# 4      31.13     -1.83               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# ...

# %%
df_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  datetime64[ns]
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
df_dep.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            59400 non-null  int64
#  1   status_group  59400 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 928.2+ KB

# %%
df_dep['status_group'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
#merge the two train dataframes- independents variable with dependent variable

# %%
df = pd.merge(df_ind,df_dep,on='id')
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572     6000.00    2011-03-14            Roman        1390
# 1       8776        0.00    2013-03-06          Grumeti        1399
# 2      34310       25.00    2013-02-25     Lottery Club         686
# 3      67743        0.00    2013-01-28           Unicef         263
# 4      19728        0.00    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739       10.00    2013-05-03  Germany Republi        1210
# 59396  27263     4700.00    2011-05-07      Cefa-njombe        1212
# 59397  37057        0.00    2011-04-11              NaN           0
# 59398  31282        0.00    2011-03-08            Malec           0
# 59399  26348        0.00    2011-03-23       World Bank         191
#
#           installer  longitude  latitude              wpt_name  num_private  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  datetime64[ns]
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
df_new = df[["source_type", "water_quality", "waterpoint_type", "status_group", "construction_year"]].copy()

# %%
df_new.isna().sum()
# Out:
# source_type          0
# water_quality        0
# waterpoint_type      0
# status_group         0
# construction_year    0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   source_type        59400 non-null  object
#  1   water_quality      59400 non-null  object
#  2   waterpoint_type    59400 non-null  object
#  3   status_group       59400 non-null  object
#  4   construction_year  59400 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.7+ MB

# %%
df_new['status_group'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
#bin target "status group" using If statments before train/test split "status_group_new"sg_new = []
sg_new = []
for sg in df_new['status_group']:
    if sg == 'functional':
        sg_new.append(1)
    else:
        sg_new.append(0)
df_new["sg_new"] = sg_new

# %%
#Status vs source type
# %matplotlib inline
pd.crosstab(df_new.source_type,df_new.sg_new).plot(kind='bar')
plt.title('Functional Status vs Source Type')
plt.xlabel('Source Type')
plt.ylabel('Frequency of Functionality');

# %%
#Status vs water quality
# %matplotlib inline
pd.crosstab(df_new.water_quality,df_new.sg_new).plot(kind='bar')
plt.title('Functional Status vs Water Quality')
plt.xlabel('Water Quality')
plt.ylabel('Frequency of Functionality');

# %%
# %matplotlib inline
pd.crosstab(df_new.loc[df_new['water_quality'] != 'soft'],df_new.sg_new).plot(kind='bar')
plt.title('Functional Status vs Water Quality')
plt.xlabel('Water Quality')
plt.ylabel('Frequency of Functionality');
# df_new.loc[df_new['water_quality'] != 'soft']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1683         blocks = form_blocks(arrays, names, axes)
# -> 1684         mgr = BlockManager(blocks, axes)
#    1685         mgr._consolidate_inplace()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#
# ...

# %%
df_new.water_quality

# %%
#Status vs waterpoint_type
# %matplotlib inline
pd.crosstab(df_new.waterpoint_type,df_new.sg_new).plot(kind='bar')
plt.title('Functional Status vs Waterpoint Type')
plt.xlabel('Waterpoint Type')
plt.ylabel('Frequency of Functionality');

# %%
df_new.drop(df_new[df_new['construction_year'] == 0].index, inplace = True)

# %%
df_new
# Out:
#                 source_type water_quality              waterpoint_type  \
# 0                    spring          soft           communal standpipe
# 1      rainwater harvesting          soft           communal standpipe
# 2                       dam          soft  communal standpipe multiple
# 3                  borehole          soft  communal standpipe multiple
# 5                     other         salty  communal standpipe multiple
# ...                     ...           ...                          ...
# 59391            river/lake          soft           communal standpipe
# 59394              borehole          soft           communal standpipe
# 59395                spring          soft           communal standpipe
# 59396            river/lake          soft           communal standpipe
# 59399          shallow well         salty                    hand pump
#
#          status_group  construction_year  sg_new construction_decades
# ...

# %%
#Status vs construction year
# %matplotlib inline
pd.crosstab(df_new.construction_year,df_new.sg_new).plot(kind='bar', figsize= (100,100))
plt.title('Functional Status vs Construction Year', fontsize = 100)
plt.xlabel('Construction Year', fontsize = 70)
plt.ylabel('Frequency of Functionality', fontsize = 70)
plt.xticks(rotation = 90, fontsize = 70);

# %%
def decades(year):
    #Returns unknown if value not recorded
    if year == 0:
        return 'Unknown'
    else:
        return str((year // 10) * 10)
#Apply mapping to column
df_new['construction_decades'] = df_new['construction_year'].apply(decades)

# %%
df_new.drop(['construction_year'], axis=1, inplace= True)

# %%
#Status vs construction year
# %matplotlib inline
pd.crosstab(df_new.construction_decades,df_new.sg_new).plot(kind='bar', figsize= (80,80))
plt.title('Functional Status vs Construction Decades', fontsize = 80)
plt.xlabel('Construction Decades', fontsize = 70)
plt.ylabel('Frequency of Functionality', fontsize = 70)
plt.xticks(rotation = 25, fontsize = 70);

# %%
df_new

# %%
# partion features and target 
X = df_new.drop('sg_new', axis=1)
y = df_new['sg_new']

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train_new = pd.get_dummies(X_train)

# %%
X_test_new = pd.get_dummies(X_test)

# %%
X_test_new

# %%
# 1st Model - Dummy Model
# Let's start with a completely "dummy" model, that will always choose the majority class. 

# Instantiate and fit the model on our data
dummy_model = DummyClassifier(strategy="most_frequent")
dummy_model.fit(X_train_new, y_train)

#We should expect all predictions to be the same
y_dummy_pred = dummy_model.predict(X_train)
dummy_model.score(X_train_new, y_train)

# %%
# our dummy model is roughly 56% accurate

# %%
#confusion matrix
plot_confusion_matrix(dummy_model, X_train_new, y_train)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train, y_dummy_pred))

# %%
#logreg 1

# %%
# build classifier
logreg_1 = LogisticRegression(random_state=42)
logreg_1.fit(X_train_new, y_train)

# %%
plot_confusion_matrix(logreg_1, X_test_new, y_test);

# %% [markdown]
# As you can see, our model is overfitting, so we are going to decrease regularization to account for this

# %%
test_preds = logreg_1.predict(X_test_new)

# %%
print(classification_report(y_test, test_preds))

# %%
#logreg 2

# %%
# build classifier
logreg_2 = LogisticRegression(penalty = 'l1', solver = 'saga', random_state=60)
logreg_2.fit(X_train_new, y_train)

# %%
plot_confusion_matrix(logreg_2, X_test_new, y_test);

# %%
test_preds_2 = logreg_2.predict(X_test_new)

# %%
print(classification_report(y_test, test_preds_2))
